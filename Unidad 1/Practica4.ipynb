# %% [markdown]
# <a href="https://colab.research.google.com/github/MaluDeLaCruz/Probabilidad-y-Estadistica/blob/main/Unidad%201/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# #**Probabilidad y Estadística**
#
# ##Unidad 1
#
# ##Practica 4. Estadística descriptiva básica e Histogramas.
#
# ###Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# ###Alumna: Malu De La Cruz Sotelo

# %%
import random
edades = []
#ciclo para generar 100 numeros aleatorios
for i in range(100):
  #numeros en rango de 18 a 70 años
  numero_aleatorio = random.randint(18,70)
  #lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [47, 58, 25, 32, 54, 22, 31, 56, 28, 53, 51, 48, 25, 67, 58, 65, 63, 33, 68, 26, 23, 47, 64, 34, 63, 65, 60, 46, 47, 64, 35, 58, 53, 59, 59, 33, 44, 28, 50, 23, 56, 69, 44, 21, 23, 44, 34, 61, 40, 21, 18, 47, 44, 62, 53, 57, 69, 41, 53, 18, 69, 47, 39, 61, 44, 50, 65, 45, 25, 19, 57, 39, 41, 67, 19, 67, 24, 21, 67, 69, 60, 31, 53, 47, 37, 67, 28, 25, 29, 60, 39, 48, 32, 69, 53, 65, 26, 20, 22, 68]

# %%
import pandas as pd

# %%
#crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    47
# 1    58
# 2    25
# 3    32
# 4    54

# %%
#calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
#imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 19    18           2
# 15    19           2
# 41    20           1
# 8     21           3
# 23    22           2
# 10    23           3
# 33    24           1
# 5     25           4
# 24    26           2
# 12    28           3
# 31    29           1
# 22    31           2
# 16    32           2
# 25    33           2
# 27    34           2
# 35    35           1
# 32    37           1
# 7     39           3
# 38    40           1
# 17    41           2
# 4     44           5
# 34    45           1
# 36    46           1
# 0     47           6
# 13    48           2
# 21    50           2
# 40    51           1
# 1     53           6
# 39    54           1
# 26    56           2
# 18    57           2
# 9     58           3
# 14    59           2
# 11    60           3
# 20    61           2
# 37    62           1
# 29    63           2
# 28    64           2
# 6     65           4
# 2     67           5
# 30    68           2
# 3     69           5

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 19    18           2           0.02
# 15    19           2           0.02
# 41    20           1           0.01
# 8     21           3           0.03
# 23    22           2           0.02
# 10    23           3           0.03
# 33    24           1           0.01
# 5     25           4           0.04
# 24    26           2           0.02
# 12    28           3           0.03
# 31    29           1           0.01
# 22    31           2           0.02
# 16    32           2           0.02
# 25    33           2           0.02
# 27    34           2           0.02
# 35    35           1           0.01
# 32    37           1           0.01
# 7     39           3           0.03
# 38    40           1           0.01
# 17    41           2           0.02
# 4     44           5           0.05
# 34    45           1           0.01
# 36    46           1           0.01
# 0     47           6           0.06
# 13    48           2           0.02
# 21    50           2           0.02
# 40    51           1           0.01
# 1     53           6           0.06
# 39    54           1           0.01
# 26    56           2           0.02
# 18    57           2           0.02
# 9     58           3           0.03
# 14    59           2           0.02
# 11    60           3           0.03
# 20    61           2           0.02
# 37    62           1           0.01
# 29    63           2           0.02
# 28    64           2           0.02
# 6     65           4           0.04
# 2     67           5           0.05
# 30    68           2           0.02
# 3     69           5           0.05

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual
# 19    18           2           0.02              2.0
# 15    19           2           0.02              2.0
# 41    20           1           0.01              1.0
# 8     21           3           0.03              3.0
# 23    22           2           0.02              2.0
# 10    23           3           0.03              3.0
# 33    24           1           0.01              1.0
# 5     25           4           0.04              4.0
# 24    26           2           0.02              2.0
# 12    28           3           0.03              3.0
# 31    29           1           0.01              1.0
# 22    31           2           0.02              2.0
# 16    32           2           0.02              2.0
# 25    33           2           0.02              2.0
# 27    34           2           0.02              2.0
# 35    35           1           0.01              1.0
# 32    37           1           0.01              1.0
# 7     39           3           0.03              3.0
# 38    40           1           0.01              1.0
# 17    41           2           0.02              2.0
# 4     44           5           0.05              5.0
# 34    45           1           0.01              1.0
# 36    46           1           0.01              1.0
# 0     47           6           0.06              6.0
# 13    48           2           0.02              2.0
# 21    50           2           0.02              2.0
# 40    51           1           0.01              1.0
# 1     53           6           0.06              6.0
# 39    54           1           0.01              1.0
# 26    56           2           0.02              2.0
# 18    57           2           0.02              2.0
# 9     58           3           0.03              3.0
# 14    59           2           0.02              2.0
# 11    60           3           0.03              3.0
# 20    61           2           0.02              2.0
# 37    62           1           0.01              1.0
# 29    63           2           0.02              2.0
# 28    64           2           0.02              2.0
# 6     65           4           0.04              4.0
# 2     67           5           0.05              5.0
# 30    68           2           0.02              2.0
# 3     69           5           0.05              5.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual  Frec Acumulada
# 19    18           2           0.02              2.0               2
# 15    19           2           0.02              2.0               4
# 41    20           1           0.01              1.0               5
# 8     21           3           0.03              3.0               8
# 23    22           2           0.02              2.0              10
# 10    23           3           0.03              3.0              13
# 33    24           1           0.01              1.0              14
# 5     25           4           0.04              4.0              18
# 24    26           2           0.02              2.0              20
# 12    28           3           0.03              3.0              23
# 31    29           1           0.01              1.0              24
# 22    31           2           0.02              2.0              26
# 16    32           2           0.02              2.0              28
# 25    33           2           0.02              2.0              30
# 27    34           2           0.02              2.0              32
# 35    35           1           0.01              1.0              33
# 32    37           1           0.01              1.0              34
# 7     39           3           0.03              3.0              37
# 38    40           1           0.01              1.0              38
# 17    41           2           0.02              2.0              40
# 4     44           5           0.05              5.0              45
# 34    45           1           0.01              1.0              46
# 36    46           1           0.01              1.0              47
# 0     47           6           0.06              6.0              53
# 13    48           2           0.02              2.0              55
# 21    50           2           0.02              2.0              57
# 40    51           1           0.01              1.0              58
# 1     53           6           0.06              6.0              64
# 39    54           1           0.01              1.0              65
# 26    56           2           0.02              2.0              67
# 18    57           2           0.02              2.0              69
# 9     58           3           0.03              3.0              72
# 14    59           2           0.02              2.0              74
# 11    60           3           0.03              3.0              77
# 20    61           2           0.02              2.0              79
# 37    62           1           0.01              1.0              80
# 29    63           2           0.02              2.0              82
# 28    64           2           0.02              2.0              84
# 6     65           4           0.04              4.0              88
# 2     67           5           0.05              5.0              93
# 30    68           2           0.02              2.0              95
# 3     69           5           0.05              5.0             100

# %% [markdown]
# #Regla de Sturges

# %%
#libreria math de funciones matematicas
import math

# %%
print(edades)
# Out:
# [47, 58, 25, 32, 54, 22, 31, 56, 28, 53, 51, 48, 25, 67, 58, 65, 63, 33, 68, 26, 23, 47, 64, 34, 63, 65, 60, 46, 47, 64, 35, 58, 53, 59, 59, 33, 44, 28, 50, 23, 56, 69, 44, 21, 23, 44, 34, 61, 40, 21, 18, 47, 44, 62, 53, 57, 69, 41, 53, 18, 69, 47, 39, 61, 44, 50, 65, 45, 25, 19, 57, 39, 41, 67, 19, 67, 24, 21, 67, 69, 60, 31, 53, 47, 37, 67, 28, 25, 29, 60, 39, 48, 32, 69, 53, 65, 26, 20, 22, 68]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     47
# 1     58
# 2     25
# 3     32
# 4     54
# ..   ...
# 95    65
# 96    26
# 97    20
# 98    22
# 99    68
#
# [100 rows x 1 columns]

# %%
#calcular el numero de intervalos utilizando la regla de sturges
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n = ",n ,"\nNúmero de intervalos =",k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
#crear tabla de frecuencias
tabla_frecuencia = pd.cut(df['Edad'],bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (61.714, 69.0]    21
# 1  (17.948, 25.286]    18
# 2  (39.857, 47.143]    16
# 3  (54.429, 61.714]    14
# 4  (47.143, 54.429]    12
# 5  (25.286, 32.571]    10
# 6  (32.571, 39.857]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.948, 25.286]    18
# 5  (25.286, 32.571]    10
# 6  (32.571, 39.857]     9
# 2  (39.857, 47.143]    16
# 4  (47.143, 54.429]    12
# 3  (54.429, 61.714]    14
# 0    (61.714, 69.0]    21

# %%
#generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.948, 25.286]    18      0.18       18.0       18         0.18
# 5  (25.286, 32.571]    10      0.10       10.0       28         0.28
# 6  (32.571, 39.857]     9      0.09        9.0       37         0.37
# 2  (39.857, 47.143]    16      0.16       16.0       53         0.53
# 4  (47.143, 54.429]    12      0.12       12.0       65         0.65
# 3  (54.429, 61.714]    14      0.14       14.0       79         0.79
# 0    (61.714, 69.0]    21      0.21       21.0      100         1.00
#
#    Frec Porc Ac
# 1          18.0
# 5          28.0
# 6          37.0
# 2          53.0
# 4          65.0
# 3          79.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha=0.5, bins=20)
plt.title("Histograma de edades basado en la función de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estandar')

# %%
#histograma basado en la tabla de frecuencias
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #Practica 5. Diagrama de cajas y bigotes

# %%
import random
edades2=[]
#ciclo para generar 100 numeros aleatorios
for i in range(100):
  #numeros en rango de 18 a 70 años
  numero_aleatorio = random.randint(18,70)
  #lista de valores
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [33, 69, 45, 59, 56, 37, 68, 61, 32, 40, 54, 69, 21, 64, 30, 33, 51, 46, 51, 36, 70, 64, 63, 57, 22, 34, 70, 67, 63, 39, 51, 60, 39, 26, 55, 61, 36, 34, 48, 57, 49, 66, 37, 18, 65, 36, 27, 32, 32, 43, 63, 30, 59, 39, 42, 36, 36, 44, 64, 38, 40, 42, 39, 19, 36, 40, 68, 28, 60, 29, 44, 54, 42, 64, 40, 22, 23, 35, 38, 68, 38, 32, 61, 62, 70, 48, 69, 35, 33, 69, 60, 41, 56, 29, 51, 29, 56, 53, 67, 29]

# %%
fig, (ax1,ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuenta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuenta 2')
plt.show()

# %%
#agregar una edad mas a la lista
edades2.append(130)

# %%
fig, (ax1,ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuenta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuenta 2')
plt.show()
