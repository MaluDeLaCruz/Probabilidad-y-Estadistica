# %% [markdown]
# <a href="https://colab.research.google.com/github/MaluDeLaCruz/Probabilidad-y-Estadistica/blob/main/Unidad%201/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# #**Probabilidad y Estadística**
#
# ##Unidad 1
#
# ##Practica 1. Estadística descriptiva básica e Histogramas.
#
# ###Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# ###Alumna: Malu De La Cruz Sotelo

# %%
from statistics import *

# %%
#Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#Sacar la media de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
#Determinar la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
#determinar multiples modas en caso de que existan con la funcion multimode
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %% [markdown]
# #EJEMPLO 2. TIEMPOS DE 100 METROS DE UN GRUPO DE 12 ALUMNOS

# %%
tiempos100mts = [15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#calcular el promedio
print("El tiempo promedio de los corredores es =>", mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es => 17.322

# %%
#calcular la mediana
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es =>", mediana)
# Out:
# La media de los tiempos de los corredores es => 17.2

# %%
#calcular la moda
moda = mode(tiempos100mts)
print("La moda de los tiempos de los corredores es =>", moda)
# Out:
# La moda de los tiempos de los corredores es => 15.1

# %%
#calcular multimodas
multimoda = multimode(tiempos100mts)
print("La moda de los tiempos de los corredores es =>", multimoda)
# Out:
# La moda de los tiempos de los corredores es => [15.1, 17.2]

# %% [markdown]
# #EJEMPLO 3. Histogramas de 2 grupos

# %%
#libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [52.83, 58.88, 87.41, 75.19, 81.16, 53.01, 59.66, 61.18, 98.46, 84.13, 94.48, 91.66, 96.83, 98.17, 70.07, 92.59, 90.49, 79.75, 69.31, 51.13, 68.82, 90.11, 54.23, 72.55, 96.93, 50.01, 65.3, 83.18, 54.46, 99.28, 89.45, 75.42, 79.85, 83.53, 95.44, 77.81, 59.05, 91.65, 90.47, 82.42, 53.2, 76.72, 84.03, 61.84, 51.81, 81.4, 78.28, 55.91, 65.82, 85.9, 85.29, 75.96, 59.84, 81.13, 57.65, 96.67, 66.12, 97.06, 93.73, 90.01, 64.77, 99.66, 71.9, 60.43, 82.29, 85.38, 58.37, 80.48, 97.58, 98.06, 93.54, 91.94, 69.9, 60.64, 60.91, 67.43, 73.46, 57.44, 71.52, 70.34, 86.07, 76.33, 93.55, 82.18, 69.78, 70.0, 64.52, 78.33, 62.73, 71.01, 73.8, 55.32, 61.49, 99.72, 78.95, 81.07, 93.58, 86.61, 93.89, 82.25]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [74.04, 84.49, 50.14, 53.94, 63.88, 98.66, 60.17, 54.13, 93.4, 76.87, 51.65, 90.29, 75.28, 93.11, 80.58, 89.88, 98.37, 52.65, 65.31, 55.57, 93.42, 68.83, 55.71, 83.33, 58.86, 62.83, 69.21, 73.36, 89.85, 50.73, 60.19, 53.86, 61.9, 61.28, 67.41, 86.09, 94.31, 69.71, 83.12, 50.28, 75.35, 53.7, 88.34, 90.33, 89.32, 59.78, 74.48, 52.2, 83.83, 90.33, 53.59, 92.17, 63.46, 55.55, 66.61, 63.47, 83.38, 63.44, 80.59, 55.6, 74.96, 98.84, 58.47, 72.51, 85.92, 92.37, 65.62, 94.54, 88.59, 61.14, 50.34, 71.37, 96.6, 80.14, 95.35, 66.75, 61.38, 89.82, 54.76, 56.89, 90.3, 72.14, 51.89, 99.27, 91.84, 75.07, 72.08, 65.83, 82.89, 96.78, 77.06, 89.26, 73.22, 67.93, 61.12, 89.9, 94.58, 95.32, 95.36, 75.93]

# %%
#importat libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es =>",media1)
print("La mediana es =>",mediana1)
print("La moda es =>",moda1)
# Out:
# Valores de la fabrica 1
# La media es => 76.8194
# La mediana es => 78.305
# La moda es => 52.83

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media es =>",media2)
print("La mediana es =>",mediana2)
print("La moda es =>",moda2)
# Out:
# Valores de la fabrica 2
# La media es => 74.2634
# La mediana es => 73.7
# La moda es => 90.33

# %%
#generar 2 subplot de 1 renglon por dos columnas para desplegar los 2 histogramas
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1,bins=10,alpha=0.2, color='b',edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2,bins=10,alpha=0.2, color='b',edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 2")
plt.legend()
plt.show()
